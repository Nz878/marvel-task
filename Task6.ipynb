# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.load(r"C:\Users\naman\OneDrive\Desktop\encoded_array.npy")
plt.imshow(data)
plt.show()
data = data.T
plt.imshow(data)
plt.show()
data.resize(100,100)
plt.imshow(data)
plt.show()
