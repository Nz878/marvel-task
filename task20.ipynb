# %% [markdown]
# # Quest 1
#
# ## 3 things I want to learn
# * I want to learn Japanese
# * I want to learn python language
# * I want to learn more about AI
#
# ##  Formating text
# **BOLD**
# <br>*ITALIC TEXT*
# ***

# %% [markdown]
# # Quest 2

# %%
x=2
y=3
sum=x+y
print(sum)
# Out:
# 5

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[1,4,9,16,25]
plt.plot(x, y, marker="o")
plt.title("y = x^2")
plt.xlabel("x values")
plt.ylabel("y values")
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# # CONCLUSION
#
# Jupyter Notebook is not only a software where you can write and run code, but also a way to manage and document it easily and neatly.
# It helps us build confidence in combining code, comments, and visualisations.
